# %%
import requests
import json

# Define API endpoint and your API key (or token)
API_URL = 'https://api.gemini.google.com/v1/complete'
API_KEY = 'your_api_key_here'

# Function to send a request to the Gemini API and get the response
def chat_with_gemini(user_message):
    headers = {
        'Authorization': f'Bearer {API_KEY}',
        'Content-Type': 'application/json',
    }

    # Construct the request payload
    payload = {
        'messages': [
            {
                'role': 'user',
                'content': user_message
            }
        ]
    }

    # Send the request
    response = requests.post(API_URL, headers=headers, data=json.dumps(payload))

    if response.status_code == 200:
        # Parse and return the model's response
        response_data = response.json()
        return response_data.get('choices', [{}])[0].get('message', {}).get('content', 'No response')
    else:
        return f"Error: {response.status_code}"

# Main conversation loop
def start_chat():
    print("ChatBot: Hello! I'm your Gemini-powered assistant. Type 'exit' to end the chat.")

    while True:
        user_input = input("You: ")

        if user_input.lower() == 'exit':
            print("ChatBot: Goodbye!")
            break

        response = chat_with_gemini(user_input)
        print(f"ChatBot: {response}")

# Run the chat
if __name__ == "__main__":
    start_chat()
# Out:
# ChatBot: Hello! I'm your Gemini-powered assistant. Type 'exit' to end the chat.

# %%
import openai

# Set your OpenAI API key
openai.api_key = "your_openai_api_key_here"

# Function to send a request to OpenAI GPT-3.5 or GPT-4 and get the response
def chat_with_openai(user_message):
    response = openai.Completion.create(
        engine="gpt-4",  # or "gpt-3.5-turbo" if you prefer
        prompt=user_message,
        max_tokens=150
    )
    return response.choices[0].text.strip()

# Main conversation loop
def start_chat():
    print("ChatBot: Hello! I'm your OpenAI-powered assistant. Type 'exit' to end the chat.")

    while True:
        user_input = input("You: ")

        if user_input.lower() == 'exit':
            print("ChatBot: Goodbye!")
            break

        response = chat_with_openai(user_input)
        print(f"ChatBot: {response}")

# Run the chat
if __name__ == "__main__":
    start_chat()
# Out:
# ChatBot: Hello! I'm your OpenAI-powered assistant. Type 'exit' to end the chat.
# You: Hello
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# <ipython-input-12-bb2bd91b33b2> in <cell line: 0>()
#      29 # Run the chat
#      30 if __name__ == "__main__":
# ---> 31     start_chat()
#
# <ipython-input-12-bb2bd91b33b2> in start_chat()
#      24             break
#      25
# ---> 26         response = chat_with_openai(user_input)
#      27         print(f"ChatBot: {response}")
#      28
#
# <ipython-input-12-bb2bd91b33b2> in chat_with_openai(user_message)
#       6 # Function to send a request to OpenAI GPT-3.5 or GPT-4 and get the response
#       7 def chat_with_openai(user_message):
# ----> 8     response = openai.Completion.create(
#       9         engine="gpt-4",  # or "gpt-3.5-turbo" if you prefer
#      10         prompt=user_message,
#
# ...

# %%
pip install --upgrade openai
import openai

# Set your OpenAI API key
openai.api_key = "your_openai_api_key_here"

# Function to send a request to OpenAI's GPT model and get the response
def chat_with_openai(user_message):
    response = openai.chat_completions.create(
        model="gpt-4",  # or "gpt-3.5-turbo" if you prefer
        messages=[
            {"role": "user", "content": user_message}
        ]
    )
    return response['choices'][0]['message']['content']

# Main conversation loop
def start_chat():
    print("ChatBot: Hello! I'm your OpenAI-powered assistant. Type 'exit' to end the chat.")

    while True:
        user_input = input("You: ")

        if user_input.lower() == 'exit':
            print("ChatBot: Goodbye!")
            break

        response = chat_with_openai(user_input)
        print(f"ChatBot: {response}")

# Run the chat
if __name__ == "__main__":
    start_chat()

# %%
pip install --upgrade openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.2/661.2 kB 38.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.75.0
#     Uninstalling openai-1.75.0:
#       Successfully uninstalled openai-1.75.0
# ...
